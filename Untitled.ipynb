# %%
# !pip list
# Out:
# /usr/bin/zsh: /home/jack/anaconda3/envs/trading_env/lib/libtinfo.so.6: no version information available (required by /usr/bin/zsh)
# Package                      Version
# ---------------------------- ---------
# absl-py                      1.4.0
# aiofiles                     22.1.0
# aiosqlite                    0.18.0
# anyio                        3.6.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        22.2.0
# Babel                        2.12.1
# backcall                     0.2.0
# beautifulsoup4               4.11.2
# bleach                       6.0.0
# Bottleneck                   1.3.5
# cachetools                   5.3.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           3.0.1
# comm                         0.1.2
# ...
